# %%
from IPython.display import HTML, Audio
from google.colab.output import eval_js
from base64 import b64decode
import numpy as np
import io
from PIL import Image
from google.colab.patches import cv2_imshow

# %%
VIDEO_HTML = """
<video autoplay
 width=%d height=%d style='cursor: pointer;'></video>
<script>

var video = document.querySelector('video')

navigator.mediaDevices.getUserMedia({ video: true })
  .then(stream=> video.srcObject = stream)
  
/* var data = */
/* Waits for the promise to execture the on click function */
var data = new Promise(resolve=>{
  video.onclick = ()=>{
    var canvas = document.createElement('canvas')
    var [w,h] = [video.offsetWidth, video.offsetHeight]
    canvas.width = w
    canvas.height = h
    canvas.getContext('2d')
          .drawImage(video, 0, 0, w, h)
    video.srcObject.getVideoTracks()[0].stop()
    video.replaceWith(canvas)
    resolve(canvas.toDataURL('image/jpeg', %f))
  }
})
</script>
"""

# %%
def take_photo(filename='photo.jpg', quality=0.8, size=(800,600)):
  display(HTML(VIDEO_HTML % (size[0],size[1],quality)))
  ## Screen capture right here
  data = eval_js("data")
  binary = b64decode(data.split(',')[1])
  f = io.BytesIO(binary)
  return np.asarray(Image.open(f))

# %%
img = take_photo() # click
cv2_imshow(img)
# Out:
# <video autoplay
#  width=800 height=600 style='cursor: pointer;'></video>
# <script>
#
# var video = document.querySelector('video')
#
# navigator.mediaDevices.getUserMedia({ video: true })
#   .then(stream=> video.srcObject = stream)
#
# var data = new Promise(resolve=>{
#   video.onclick = ()=>{
#     var canvas = document.createElement('canvas')
#     var [w,h] = [video.offsetWidth, video.offsetHeight]
#     canvas.width = w
#     canvas.height = h
#     canvas.getContext('2d')
#           .drawImage(video, 0, 0, w, h)
#     video.srcObject.getVideoTracks()[0].stop()
#     video.replaceWith(canvas)
#     resolve(canvas.toDataURL('image/jpeg', 0.800000))
#   }
# })
# </script>
# <PIL.Image.Image image mode=RGB size=800x600 at 0x7F438FE5F240>

# %%
# !git commit -m
# Out:
# fatal: not a git repository (or any of the parent directories): .git
